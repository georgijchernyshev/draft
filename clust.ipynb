# %%
import os

# %%
os.chdir(r"C:\Users\georg\OneDrive\Desktop\st\temp_modulation\gas-sensor-array-temperature-modulation")

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.style.use("seaborn-v0_8-colorblind")

# %%
df = pd.read_csv("20160930_203718.csv", sep=',')

# %%
df
# Out:
#          Time (s)  CO (ppm)  Humidity (%r.h.)  Temperature (C)  \
# 0           0.000       0.0           49.7534          23.7184
# 1           0.309       0.0           55.8400          26.6200
# 2           0.618       0.0           55.8400          26.6200
# 3           0.926       0.0           55.8400          26.6200
# 4           1.234       0.0           55.8400          26.6200
# ...           ...       ...               ...              ...
# 295714  90908.545       0.0           62.3000          26.5800
# 295715  90908.853       0.0           62.3000          26.5800
# 295716  90909.162       0.0           62.3000          26.5800
# 295717  90909.469       0.0           62.3000          26.5800
# 295718  90909.778       0.0           62.3000          26.5800
#
#         Flow rate (mL/min)  Heater voltage (V)  R1 (MOhm)  R2 (MOhm)  \
# 0                 233.2737              0.8993     0.2231     0.6365
# ...

# %%
df.shape
# Out:
# (295719, 20)

# %%
df.describe()
# Out:
#             Time (s)       CO (ppm)  Humidity (%r.h.)  Temperature (C)  \
# count  295719.000000  295719.000000     295719.000000    295719.000000
# mean    45457.823660       9.900786         45.966022        26.476381
# std     26242.177649       6.429229         12.315889         0.211647
# min         0.000000       0.000000         17.500000        23.718400
# 25%     22727.738500       4.440000         36.170000        26.300000
# 50%     45460.834000       8.890000         46.670000        26.460000
# 75%     68177.907000      15.560000         55.330000        26.620000
# max     90909.778000      20.000000         71.960000        26.940000
#
#        Flow rate (mL/min)  Heater voltage (V)      R1 (MOhm)      R2 (MOhm)  \
# count       295719.000000       295719.000000  295719.000000  295719.000000
# mean           239.942669            0.355293      14.962249      17.396103
# std              1.947498            0.288663      22.368187      26.648398
# ...

# %% [markdown]
# #### данные сильно отличаются порядками, будем использовать standart scaler

# %%
df.dtypes.value_counts()
# Out:
# float64    20
# dtype: int64

# %%
columns = df.columns

# %%
columns
# Out:
# Index(['Time (s)', 'CO (ppm)', 'Humidity (%r.h.)', 'Temperature (C)',
#        'Flow rate (mL/min)', 'Heater voltage (V)', 'R1 (MOhm)', 'R2 (MOhm)',
#        'R3 (MOhm)', 'R4 (MOhm)', 'R5 (MOhm)', 'R6 (MOhm)', 'R7 (MOhm)',
#        'R8 (MOhm)', 'R9 (MOhm)', 'R10 (MOhm)', 'R11 (MOhm)', 'R12 (MOhm)',
#        'R13 (MOhm)', 'R14 (MOhm)'],
#       dtype='object')

# %%
fig = plt.figure(figsize=(20,30))

plt.matshow(df.corr())
cb = plt.colorbar()
plt.show()

# %%
df2 = pd.read_csv("20161001_231809.csv")
res = pd.concat([df, df2])
res
# Out:
#          Time (s)  CO (ppm)  Humidity (%r.h.)  Temperature (C)  \
# 0           0.000       0.0           49.7534          23.7184
# 1           0.309       0.0           55.8400          26.6200
# 2           0.618       0.0           55.8400          26.6200
# 3           0.926       0.0           55.8400          26.6200
# 4           1.234       0.0           55.8400          26.6200
# ...           ...       ...               ...              ...
# 295511  90908.366       0.0           62.2800          26.4200
# 295512  90908.671       0.0           62.2800          26.4200
# 295513  90908.976       0.0           62.2800          26.4200
# 295514  90909.281       0.0           62.2800          26.4200
# 295515  90909.585       0.0           62.2800          26.4200
#
#         Flow rate (mL/min)  Heater voltage (V)  R1 (MOhm)  R2 (MOhm)  \
# 0                 233.2737              0.8993     0.2231     0.6365
# ...

# %%
df.shape
# Out:
# (295719, 20)

# %% [markdown]
# сразу видно, что датчики FIGARO TGS 3870 A-04 и датчики FIS SB-500-12 сильно коррелируют между собой, можно будет понижать размерность

# %%
df.plot.scatter(x=17, y=19)
# Out:
# <Axes: xlabel='R12 (MOhm)', ylabel='R14 (MOhm)'>

# %%
df
# Out:
#          Time (s)  CO (ppm)  Humidity (%r.h.)  Temperature (C)  \
# 0           0.000       0.0           49.7534          23.7184
# 1           0.309       0.0           55.8400          26.6200
# 2           0.618       0.0           55.8400          26.6200
# 3           0.926       0.0           55.8400          26.6200
# 4           1.234       0.0           55.8400          26.6200
# ...           ...       ...               ...              ...
# 295714  90908.545       0.0           62.3000          26.5800
# 295715  90908.853       0.0           62.3000          26.5800
# 295716  90909.162       0.0           62.3000          26.5800
# 295717  90909.469       0.0           62.3000          26.5800
# 295718  90909.778       0.0           62.3000          26.5800
#
#         Flow rate (mL/min)  Heater voltage (V)  R1 (MOhm)  R2 (MOhm)  \
# 0                 233.2737              0.8993     0.2231     0.6365
# ...

# %%
x = df.drop(columns=[columns[0]])
# Out:
#         CO (ppm)  Humidity (%r.h.)  Temperature (C)  Flow rate (mL/min)  \
# 0            0.0           49.7534          23.7184            233.2737
# 1            0.0           55.8400          26.6200            241.6323
# 2            0.0           55.8400          26.6200            241.3888
# 3            0.0           55.8400          26.6200            241.1461
# 4            0.0           55.8400          26.6200            240.9121
# ...          ...               ...              ...                 ...
# 295714       0.0           62.3000          26.5800              0.0000
# 295715       0.0           62.3000          26.5800              0.0000
# 295716       0.0           62.3000          26.5800              0.0000
# 295717       0.0           62.3000          26.5800              0.0000
# 295718       0.0           62.3000          26.5800              0.0000
#
#         Heater voltage (V)  R1 (MOhm)  R2 (MOhm)  R3 (MOhm)  R4 (MOhm)  \
# ...

# %%
from sklearn.cluster import KMeans

x = x.drop(columns=columns[2:5])
x
# Out:
#         Heater voltage (V)  R1 (MOhm)  R2 (MOhm)  R3 (MOhm)  R4 (MOhm)  \
# 0                   0.8993     0.2231     0.6365     1.1493     0.8483
# 1                   0.2112     2.1314     5.3552     9.7569     6.3188
# 2                   0.2070    10.5318    22.5612    37.2635    17.7848
# 3                   0.2042    29.5749    49.5111    65.6318    26.1447
# 4                   0.2030    49.5111    67.0368    77.8317    27.9625
# ...                    ...        ...        ...        ...        ...
# 295714              0.2000     5.5429     2.5713    10.3815    18.5796
# 295715              0.2000     4.5527     2.1454     8.5494    18.0592
# 295716              0.2000     3.7374     1.8492     7.1062    18.0087
# 295717              0.2000     3.1197     1.6190     5.9138    17.6950
# 295718              0.2000     2.6417     1.4409     4.9396    17.0448
#
#         R5 (MOhm)  R6 (MOhm)  R7 (MOhm)  R8 (MOhm)  R9 (MOhm)  R10 (MOhm)  \
# ...

# %%
models = [KMeans(n_clusters=i, random_state=42, n_init='auto').fit(x) for i in range(5, 25)]
dist = [model.inertia_ for model in models]

# %%
plt.plot(range(5,25), dist, marker='o')
plt.xlabel('num of clusters')
plt.ylabel('sum of distances')
plt.title('Elbow method')
# Out:
# Text(0.5, 1.0, 'Elbow method')
